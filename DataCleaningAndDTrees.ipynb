# %%
import pandas as pd

# %%
df_train = pd.read_csv('data_set_ALL_AML_train.txt',sep="\t")
df_test = pd.read_csv('data_set_ALL_AML_independent.txt',sep="\t")
# df['Gene Description'] = df.index
# df=df.reset_index(drop=True)
df_train = df_train.drop(['37.1'],axis=1)
df_train.head()
# Out:
#                       Gene Description Gene Accession Number    1 call    2  \
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at -214    A -139
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at -153    A  -73
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at  -58    A   -1
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at   88    A  283
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at -295    A -264
#
#   call.1    3 call.2    4 call.3  ...   29 call.33   30 call.34   31 call.35  \
# 0      A  -76      A -135      A  ...   15       A -318       A  -32       A
# 1      A  -49      A -114      A  ... -114       A -192       A  -49       A
# 2      A -307      A  265      A  ...    2       A  -95       A   49       A
# 3      A  309      A   12      A  ...  193       A  312       A  230       P
# 4      A -376      A -419      A  ...  -51       A -139       A -367       A
#
#     32 call.36   33 call.37
# ...

# %%
df_test.head()
# Out:
#                       Gene Description Gene Accession Number   39 call   40  \
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at -342    A  -87
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at -200    A -248
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at   41    A  262
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at  328    A  295
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at -224    A -226
#
#   call.1   42 call.2   47 call.3  ...   65 call.29   66 call.30   63 call.31  \
# 0      A   22      A -243      A  ...  -62       A  -58       A -161       A
# 1      A -153      A -218      A  ... -198       A -217       A -215       A
# 2      A   17      A -163      A  ...   -5       A   63       A  -46       A
# 3      A  276      A  182      A  ...  141       A   95       A  146       A
# 4      A -211      A -289      A  ... -256       A -191       A -172       A
#
#     64 call.32   62 call.33
# ...

# %%
# df = df[~df['Gene Description'].str.contains('control')]
# df.reset_index(drop=True)
# Out:
# 0        -214
# 1        -153
# 2         -58
# 3          88
# 4        -295
# 5        -558
# 6         199
# 7        -176
# 8         252
# 9         206
# 10        -41
# 11       -831
# 12       -653
# 13       -462
# 14         75
# 15        381
# 16       -118
# 17       -565
# 18      15091
# 19          7
# 20        311
# 21       -231
# 22         21
# 23       -107
# 24        165
# 25        -78
# 26       -204
# 27         29
# 28        -61
# 29       -105
#         ...
# 7099      245
# 7100    14476
# 7101    10882
# 7102      701
# 7103     2762
# 7104     -325
# 7105      -67
# 7106      346
# 7107      -68
# 7108      229
# 7109      -14
# 7110      108
# 7111       28
# 7112      349
# 7113       61
# 7114      273
# 7115      384
# 7116     -306
# 7117    -1827
# 7118     1582
# 7119      185
# 7120      511
# 7121     -125
# 7122      389
# 7123      -37
# 7124      793
# 7125      329
# 7126       36
# 7127      191
# 7128      -37
# ...

# %%
df_train = df_train.filter(regex="^(?!call).*$",axis=1)
df_test = df_test.filter(regex="^(?!call).*$",axis=1)
# # df = df.filter(regex="^(?!call).*$", axis=1)
# df = df.filter(like="call",axis=1)
new_index_train = sorted(map(int,df_train.columns[2:]))
new_index_test = sorted(map(int,df_test.columns[2:]))
new_index_train = ['Gene Description','Gene Accession Number'] + list(map(str,new_index_train[:]))
new_index_test = ['Gene Description','Gene Accession Number'] + list(map(str,new_index_test[:]))
df_train = df_train.reindex(columns = new_index_train)
df_test = df_test.reindex(columns = new_index_test)
df_test.head()
# Out:
#                       Gene Description Gene Accession Number   39   40   41  \
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at -342  -87  -62
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at -200 -248  -23
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at   41  262   -7
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at  328  295  142
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at -224 -226 -233
#
#     42   43   44   45   46  ...   63   64   65   66   67   68   69   70   71  \
# 0   22   86 -146 -187  -56  ... -161  -48  -62  -58  -76 -154  -79  -55  -59
# 1 -153  -36  -74 -187  -43  ... -215 -531 -198 -217  -98 -136 -118  -44 -114
# 2   17 -141  170  312   43  ...  -46 -124   -5   63 -153   49  -30   12   23
# 3  276  252  174  142  177  ...  146  431  141   95  237  180   68  129  146
# 4 -211 -201  -32  114 -116  ... -172 -496 -256 -191 -215 -257 -110 -108 -171
#
#     72
# 0 -131
# 1 -126
# 2  -50
# 3  211
# ...

# %%
# df = df.rename(columns={"Gene Accession Number": "ID"})
# df.head()

# %%
# df = df[df['ID'].apply(lambda val: val>=20 and val<=1600)]

# %%
# df

# %%
# # df[df['Gene Description']=="RB1 Retinoblastoma 1 (including osteosarcoma)"]
# df = df.drop(['Gene Description'], axis=1)
# df = df.reset_index(drop=True)
# df

# %%
# df = df.T    #will do later
# df
# new_header = df.iloc[0]
# df = df[1:]
# df.columns=new_header
# df

# %% [markdown]
# ## 7 to 9

# %%
# sample = pd.read_csv('sample.txt',header=None, error_bad_lines=False)
# # sample = pd.DataFrame(sample[0].apply(lambda data: "ALL" if ("ALL" in data) else "AML"))
# sample = sample.rename(columns={0:"ALL/AML"})
# sample

# %%
# sample=sample[0:38]  #for training
# sample.shape,df.shape

# %%
# sample=sample
# sample

# %%
# df=df.reset_index(drop=True)
# df['AML/ALL']=sample
# df
